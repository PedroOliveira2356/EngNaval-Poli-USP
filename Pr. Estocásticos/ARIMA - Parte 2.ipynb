# %% [markdown]
# # Modelos Autorregressivos

# %%
import numpy as np
import pandas as pd

# %%
data1 = [13.4, 11.8, 15.3, 18.7, 18.9, 21.1, 21.9, 25.6, 26.4, 27.6,
          27.8, 32.2, 31.1, 36.7, 37.7, 37.7, 39.1, 41.4, 41.8, 44.2]

df1 = pd.DataFrame(
    data = {'Yt': data1},
)
df1.head()
# Out:
#      Yt
# 0  13.4
# 1  11.8
# 2  15.3
# 3  18.7
# 4  18.9

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,4), dpi=100)
plt.plot(df1.index, df1.Yt, color='tab:red')
plt.gca().set(title='Série Temporal', xlabel='Semanas', ylabel='Demanda')
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
from numpy import log

result = adfuller(df1.Yt.dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: 8.680626
# p-value: 1.000000

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})


# Original Series
fig, axes = plt.subplots(3, 2, sharex=True)
axes[0, 0].plot(df1.Yt); axes[0, 0].set_title('Série Original')
plot_acf(df1.Yt, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(df1.Yt.diff()); axes[1, 0].set_title('Diferenciação - 1a. Ordem')
plot_acf(df1.Yt.diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(df1.Yt.diff().diff()); axes[2, 0].set_title('Diferenciação - 2a. Ordem')
plot_acf(df1.Yt.diff().diff().dropna(), ax=axes[2, 1])

plt.show()

# %% [markdown]
# # Exemplo 2

# %%
data2 = [5.0, 4.0, 6.9, 8.0, 8.3, 8.0, 6.5, 7.3, 6.6, 6.3, 4.0, 5.4, 3.0, 6.5, 6.7,
         7.0, 5.4, 5.0, 2.8, 2.6, 4.8, 4.8, 7.7, 5.4, 4.8, 4.2, 5.8, 5.5, 6.4, 4.2,
         4.6, 4.5, 4.0, 3.3, 4.4, 3.3, 5.7, 5.9, 5.9, 8.0, 5.3, 7.1, 6.9, 5.3, 7.0,
         5.1, 4.8, 2.6, 5.5, 4.0, 5.2, 5.0, 6.4, 7.9, 6.1, 5.0, 3.6, 5.0, 3.3, 5.4]
df2 = pd.DataFrame(
    data  = {'Yt': data2})
df2.head()
# Out:
#     Yt
# 0  5.0
# 1  4.0
# 2  6.9
# 3  8.0
# 4  8.3

# %%
from statsmodels.tsa.stattools import adfuller
from numpy import log

result = adfuller(df2.Yt.dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -4.147215
# p-value: 0.000808

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,4), dpi=100)
plt.plot(df2.index, df2.Yt, color='tab:red')
plt.gca().set(title='Série Temporal 2', xlabel='Períodos', ylabel='Demanda')
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})
plot_pacf(df2.Yt.dropna())
plt.show()

# %% [markdown]
# # Exemplo 3

# %%
data3 = [ 7.5,  7.0, 6.0, 9.1, 9.5,  8.5,  9.6,  6.7, 8.3,  6.4, 8.6, 9.2, 8.5, 9.5, 10.2,
          9.0,  7.0, 8.7, 7.7, 9.6, 10.9, 10.8, 10.1, 9.0, 10.2, 8.6, 7.5, 8.6, 6.6,  6.7,
# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,4), dpi=100)
plt.plot(df4.index, df4.Yt, color='tab:red')
plt.gca().set(title='Série Temporal 4', xlabel='Períodos', ylabel='Demanda')
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
from numpy import log

result = adfuller(df4.Yt.dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -0.774562
# p-value: 0.826480

# %%
df4_d1 = df4.Yt.diff().dropna()

# %%
print(df4_d1)
# Out:
# 1      0.040001
# 2     -0.070000
# 3      0.029999
# 4      0.090000
# 5     -0.250000
#          ...
# 164    1.790000
# 165   -1.230000
# 166   -2.300000
# 167   -3.210000
# 168   -0.290000
# Name: Yt, Length: 168, dtype: float64

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,4), dpi=100)
plt.plot(df4.Yt.diff().dropna(), color='tab:red')
plt.gca().set(title='Série Temporal 4 (d=1)', xlabel='Períodos', ylabel='Demanda')
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
from numpy import log

result = adfuller(df4.Yt.diff().dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -4.047743
# p-value: 0.001180

# %%
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning)

# %%
from statsmodels.tsa.arima.model import ARIMA

# 1,1,0 ARIMA Model
model = ARIMA(df4.Yt, order=(1, 1, 0))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                     Yt   No. Observations:                  169
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                -198.096
# Date:                Tue, 19 Nov 2024   AIC                            400.191
# Time:                        08:34:36   BIC                            406.439
# Sample:                             0   HQIC                           402.727
#                                 - 169
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6421      0.042     15.339      0.000       0.560       0.724
# sigma2         0.6171      0.046     13.400      0.000       0.527       0.707
# ...
# Ljung-Box (L1) (Q):                   2.42   Jarque-Bera (JB):               147.20
# ...

# %%
from statsmodels.tsa.arima.model import ARIMA

# 0,1,1 ARIMA Model
model = ARIMA(df4.Yt, order=(0, 1, 1))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                     Yt   No. Observations:                  169
# Model:                 ARIMA(0, 1, 1)   Log Likelihood                -211.352
# Date:                Tue, 19 Nov 2024   AIC                            426.704
# Time:                        08:34:46   BIC                            432.952
# Sample:                             0   HQIC                           429.240
#                                 - 169
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.5337      0.065      8.267      0.000       0.407       0.660
# sigma2         0.7234      0.058     12.484      0.000       0.610       0.837
# ...
# Ljung-Box (L1) (Q):                   0.41   Jarque-Bera (JB):                59.13
# ...

# %%
from statsmodels.tsa.arima.model import ARIMA

# 1,1,1 ARIMA Model
model = ARIMA(df4.Yt, order=(1, 1, 1))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                     Yt   No. Observations:                  169
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -195.029
# Date:                Tue, 19 Nov 2024   AIC                            396.057
# Time:                        08:34:51   BIC                            405.429
# Sample:                             0   HQIC                           399.861
#                                 - 169
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8473      0.049     17.218      0.000       0.751       0.944
# ma.L1         -0.3801      0.070     -5.456      0.000      -0.517      -0.244
# sigma2         0.5945      0.044     13.615      0.000       0.509       0.680
# ...

# %%
from statsmodels.tsa.arima.model import ARIMA

# 2,1,0 ARIMA Model
model = ARIMA(df4.Yt, order=(2, 1, 0))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                     Yt   No. Observations:                  169
# Model:                 ARIMA(2, 1, 0)   Log Likelihood                -196.815
# Date:                Tue, 19 Nov 2024   AIC                            399.630
# Time:                        08:34:56   BIC                            409.002
# Sample:                             0   HQIC                           403.434
#                                 - 169
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5596      0.060      9.312      0.000       0.442       0.677
# ar.L2          0.1280      0.065      1.982      0.047       0.001       0.255
# sigma2         0.6076      0.046     13.289      0.000       0.518       0.697
# ...

# %%
from statsmodels.tsa.arima.model import ARIMA

# 2,1,1 ARIMA Model
model = ARIMA(df4.Yt, order=(2, 1, 1))
model_fit = model.fit()
print(model_fit.summary())
# Out:
# c:\Users\Andre\miniconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\Andre\miniconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#                                SARIMAX Results
# ...
# Dep. Variable:                     Yt   No. Observations:                  169
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                -194.288
# Date:                Tue, 19 Nov 2024   AIC                            396.576
# Time:                        08:35:02   BIC                            409.072
# Sample:                             0   HQIC                           401.648
#                                 - 169
# ...

# %%
from statsmodels.tsa.arima.model import ARIMA

# 2,1,2 ARIMA Model
model = ARIMA(df4.Yt, order=(2, 1, 2))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                     Yt   No. Observations:                  169
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -193.183
# Date:                Tue, 19 Nov 2024   AIC                            396.366
# Time:                        08:35:13   BIC                            411.986
# Sample:                             0   HQIC                           402.705
#                                 - 169
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6191      0.479      1.292      0.196      -0.320       1.558
# ar.L2          0.2345      0.395      0.593      0.553      -0.540       1.009
# ma.L1         -0.0831      0.469     -0.177      0.859      -1.002       0.835
# ...

# %%
from statsmodels.tsa.arima.model import ARIMA

# 1,1,0 ARIMA Model
model = ARIMA(df4.Yt, order=(1, 1, 0))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                     Yt   No. Observations:                  169
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                -198.096
# Date:                Tue, 19 Nov 2024   AIC                            400.191
# Time:                        08:35:18   BIC                            406.439
# Sample:                             0   HQIC                           402.727
#                                 - 169
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6421      0.042     15.339      0.000       0.560       0.724
# sigma2         0.6171      0.046     13.400      0.000       0.527       0.707
# ...
# Ljung-Box (L1) (Q):                   2.42   Jarque-Bera (JB):               147.20
# ...

# %%
# Plot residual errors
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
# Dados reais vs Previsão
#model.fit().plot_predict()
#plt.show()

# %%
# Plot residual errors
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
plot_acf(residuals, ax=ax[1])
plt.show()

# %%
from statsmodels.graphics.tsaplots import acf
acf_res = acf(residuals)

# %%
from statsmodels.graphics.tsaplots import acf
acf_res = acf(residuals)
acf_res
# Out:
# array([ 1.00000000e+00, -2.01023626e-02, -2.45609543e-02,  1.60941636e-02,
#         5.90349191e-03, -4.02436585e-02,  1.94221967e-02,  7.62432787e-03,
#        -2.50487752e-02, -2.98637725e-02,  1.81611700e-02, -1.57804892e-02,
#        -2.44990271e-02,  1.70961988e-02, -3.12942280e-03, -8.35443116e-03,
#        -1.27478615e-02, -2.15095209e-03, -8.25662191e-04, -6.30367766e-03,
#         3.19357502e-03, -2.53326364e-03, -9.85756142e-03])

# %%
# Separação dos Dados - Treinamento e Teste
train = df4.Yt[:140]
test = df4.Yt[140:]
train.head()
len(test)
# Out:
# 29
