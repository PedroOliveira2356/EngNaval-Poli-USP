# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from sympy import symbols, solve
import scipy.integrate as integrate
matplotlib.style.use('default')

# %%
t = range(1,29)
Y_t = [500, 350, 250, 400, 450, 350, 200, 300, 350, 200, 150, 400, 550, 350, 250, 550, 550, 400, 350, 600, 750, 500, 400, 650, 850, 600, 450, 700]

plt.plot(t, Y_t)
