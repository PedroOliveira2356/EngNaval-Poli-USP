# %%
from weight_formulas import *

# %%
DWT = 45100
Vs = 15.3 * 0.5144

LBP = 176.22
B = 31.97
D = 17
d = 11.9
desloc = 55000
vol_desloc = 53658.54
Pot = 9331.57

Fr = 0.189
C_b = 0.794
C_DWT = 0.82
n_crew = 26
C_M = 0.996
C_P = 0.797
C_PV = 0.913
C_WL = 0.874
A_WL = 4924.54
C_I = 0.0618
C_IL = 0.0594

C_alm = 554.09
KB = 6.29
BM_T = 6.47
BM_L = 189
KG = 8.21
GM_T = 4.31
GM_L = 186.84
LCB = 1.97

# %% [markdown]
# Weights

# %%
W_s = structural_weight(C_b, LBP, B, D, d)
print(f"Structural weight: {W_s:.2f} tons")
# Out:
# Structural weight: 7441.36 tons

# %%
W_p = propulsion_weight(Pot)
print(f"Propulsion weight: {W_p:.2f} tons")
# Out:
# Propulsion weight: 899.28 tons

# %%
W_outfit = outfit_weight(LBP, B)
print(f"Outfit weight: {W_outfit:.2f} tons")
# Out:
# Outfit weight: 1521.11 tons

# %%
W_fuel = fuel_weight(Pot, 5000, Vs)
print(f"Fuel weight: {W_fuel:.2f} tons")
# Out:
# Fuel weight: 56.32 tons

# %%
W_water = fresh_water_and_provisions_weight(n_crew, 20)
print(f"Fresh water and provisions weight: {W_water:.2f} tons")
# Out:
# Fresh water and provisions weight: 93.60 tons

# %%
W_crew = crew_weight(n_crew)
print(f"Crew weight: {W_crew:.2f} tons")
# Out:
# Crew weight: 4.42 tons

# %%
W_total = total_deadweight(DWT, W_fuel, W_water, W_crew)
print(f"Total deadweight: {W_total:.2f} tons")
# Out:
# 45274.33912997184

# %% [markdown]
# Centers

# %%
VCG_hull = vertical_center_of_gravity_hull(LBP, D, C_b)
print(f"Vertical center of gravity (hull): {VCG_hull:.2f} m")
# Out:
# Vertical center of gravity (hull): 7.96 m

# %%
LCG_hull = longitudinal_center_of_gravity_hull(LBP)
print(f"Longitudinal center of gravity (hull): {LCG_hull:.2f} m")
# Out:
# Longitudinal center of gravity (hull): 176.07 m

# %%
VCG_machinery = vertical_center_of_gravity_machinery(LBP, B, d, D)
print(f"Vertical center of gravity (machinery): {VCG_machinery:.2f} m")
# Out:
# Vertical center of gravity (machinery): 1096.96 m

# %%
VCG_outfit = vertical_center_of_gravity_outfit(LBP, D)
print(f"Vertical center of gravity (outfit): {VCG_outfit:.2f} m")
# Out:
# Vertical center of gravity (outfit): 18.76 m

# %%
LCG_machinery = longitudinal_center_of_gravity_machinery(LBP, B, d)
print(f"Longitudinal center of gravity (machinery): {LCG_machinery:.2f} m")
# Out:
# Longitudinal center of gravity (machinery): 90.12 m

# %%
KG_des = ...

# %%
trim = ...
